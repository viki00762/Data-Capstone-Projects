# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df0 = pd.read_csv('TRB Flight Safety.csv')

# %%
df0.head()

# %%
df1 = pd.read_excel('Complete Data.xlsx')

# %%
df1.head()
# Out:
#    Flight Record  P30: Event Record Flight Date (UTC)  \
# 0        5409211           10645699        2016-01-01
# 1        5409211           10645698        2016-01-01
# 2        5409501           10645625        2016-01-01
# 3        5409507           10645570        2016-01-01
# 4        5410172           10645205        2016-01-01
#
#    P30: GMT at Maximum Acceleration (normal load-factor) root mean square during event (hrs)  \
# 0                                          22.212778
# 1                                          21.806285
# 2                                           2.916910
# 3                                           1.039896
# 4                                           2.331528
#
#   Fleet Group Tail Number               ID Unnamed: 7       IDTRB  \
# 0       MD-90        9257  42370ATLSAT9257        NaN  ATLSAT9257
# 1       MD-90        9257  42370ATLSAT9257        NaN  ATLSAT9257
# 2        B737        3801  42370SJUJFK3801        NaN  SJUJFK3801
# 3        B717        9560  42370ATLEWR9560        NaN  ATLEWR9560
# 4        B737        3751  42370STIJFK3751        NaN  STIJFK3751
#
#   Takeoff Airport Code Landing Airport Code  \
# 0                  ATL                  SAT
# 1                  ATL                  SAT
# 2                  SJU                  JFK
# 3                  ATL                  EWR
# 4                  STI                  JFK
#
#    P30: Latitude at Maximum Acceleration (normal load-factor) root mean square during event (deg)  \
# 0                                          27.958179
# 1                                          29.012092
# 2                                          34.373861
# 3                                          34.470626
# 4                                          34.173478
#
#    P30: Longitude at Maximum Acceleration (normal load-factor) root mean square during event (deg)  \
# 0                                         -97.305086
# 1                                         -94.599420
# 2                                         -70.084096
# 3                                         -82.851232
# 4                                         -70.033772
#
#   P30: Severity  \
# 0       Warning
# 1       Caution
# 2       Caution
# 3       Caution
# 4       Caution
#
#    P30: Maximum Acceleration (normal load-factor) during event (g's)  \
# 0                                           1.436600
# 1                                           1.306800
# 2                                           1.215201
# 3                                           1.319976
# 4                                           1.178571
#
#    P30: Minimum Acceleration (normal load-factor) during event (g's)  \
# 0                                           0.712800
# 1                                           0.697400
# 2                                           0.672618
# 3                                           0.729672
# 4                                           0.718406
#
#    P30: Maximum Acceleration (normal load-factor) root mean square during event (g's)  \
# 0                                           0.226931
# 1                                           0.137992
# 2                                           0.134091
# 3                                           0.134491
# 4                                           0.126821
#
#    P30: Best Available MSL Altitude at Maximum Acceleration (normal load-factor) root mean square during event (ft)  \
# 0                                       25891.101380
# 1                                       25943.244757
# 2                                       32166.194114
# 3                                       27243.818371
# 4                                       36144.748292
#
#   P30: Phase of Flight
# 0           G) Enroute
# 1           G) Enroute
# 2           G) Enroute
# 3           G) Enroute
# 4           G) Enroute

# %%
from openpyxl import load_workbook

workbook = load_workbook('Complete Data.xlsx Data.xlsxplete Data.xlsx', use_iterators=True)
first_sheet = workbook.get_sheet_names()[0]
worksheet = workbook.get_sheet_by_name(first_sheet)

for row in worksheet.iter_rows():
    print row

# check out the last row
for cell in row:
    print cell

# %%
first_sheet.head()

# %%
df0.head()
